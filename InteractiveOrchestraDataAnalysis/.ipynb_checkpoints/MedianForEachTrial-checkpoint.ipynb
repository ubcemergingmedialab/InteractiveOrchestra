# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import io

# %%
data = pd.read_csv(r'/Users/williambeltran/Desktop/Projects/InteractiveOrchestra/InteractiveOrchestraDataAnalysis/CleanData.csv');

# %%
data
# Out:
#        Unnamed: 0  Unnamed: 0.1             ID GestureSize  Velocity_X  \
# 0               0             0    720.16S80T1           S   -0.300608
# 1               1             1    720.18S80T1           S   -0.381058
# 2               2             2     720.2S80T1           S   -0.479363
# 3               3             3    720.22S80T1           S   -0.479363
# 4               4             4    720.24S80T1           S   -0.571902
# 5               5             5    720.26S80T1           S   -0.628479
# 6               6             6    720.28S80T1           S   -0.650794
# 7               7             7     720.3S80T1           S   -0.650904
# 8               8             8    720.32S80T1           S   -0.632837
# 9               9             9    720.34S80T1           S   -0.560123
# 10             10            10    720.36S80T1           S   -0.471141
# 11             11            11    720.38S80T1           S   -0.363768
# ...
